# %%
# Import packages

import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cf

# %%
path = r'path\to\data'
ds = xr.open_dataset(path)
ds
# Out:
# C:\Users\ysf16568\AppData\Local\Temp\ipykernel_32684\2260907919.py:2: FutureWarning: In a future version, xarray will not decode timedelta values based on the presence of a timedelta-like units attribute by default. Instead it will rely on the presence of a timedelta64 dtype attribute, which is now xarray's default way of encoding timedelta64 values. To continue decoding timedeltas based on the presence of a timedelta-like units attribute, users will need to explicitly opt-in by passing True or CFTimedeltaCoder(decode_via_units=True) to decode_timedelta. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   ds = xr.open_dataset(path)
# <xarray.Dataset> Size: 1GB
# Dimensions:              (time: 24, bnds: 2, latitude: 720, longitude: 1440,
#                           layer: 2)
# Coordinates:
#   * time                 (time) datetime64[ns] 192B 2025-05-01T00:30:00 ... 2...
# ...

# %%
# Now you know how to use satellite data, try to plot the total column CO

### ADD CODE HERE

# Question(s): 
# What stands out in this data? 
# Why do some parts look very different to others? 
# What interesting features can you identify
# Out:
# Text(0.5, 1.0, '2025-05-01')

# %%
# Challenge: Can you plot the CO data over some of the SISEM data we showed previously?

### ADD CODE HERE

# Question(s):
# Does you plot look correct? Can you add any extra information to help you understand the data?
# What extra details/information can you see in this plot that you didn't notice before?
